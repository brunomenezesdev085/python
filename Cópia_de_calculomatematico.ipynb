# %% [markdown]
# <a href="https://colab.research.google.com/github/brunomenezesdev085/python/blob/main/C%C3%B3pia_de_calculomatematico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome:")
#pode ser dessas duas formas abaixo
idade = int (input("Digite sua idade:"))
idade = int(idade)


print(f'Olá {nome}, daqui 5 anos voce terá {idade + 5} anos de idade')

print(type(nome))
print(type(idade))
# Out:
# Digite seu nome:bruno
# Digite sua idade:19
# Olá bruno, daqui 5 anos voce terá 24 anos de idade
# <class 'str'>
# <class 'int'>
