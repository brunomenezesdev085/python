# %% [markdown]
# <a href="https://colab.research.google.com/github/brunomenezesdev085/python/blob/main/soma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 10
num2 = 2

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 0
# 100
