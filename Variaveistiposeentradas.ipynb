# %% [markdown]
# <a href="https://colab.research.google.com/github/brunomenezesdev085/python/blob/main/Variaveistiposeentradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Bruno"  #stringer
idade = 29 #integer
mensagem = 'bom dia' #stringer
altura = 1.76 #float
aluno = True #boolean

print(type(nome))
print(type(idade))
print(type(mensagem))
print(type(altura))
print(type(aluno))

print(nome)
print(idade)
print(mensagem)
print(altura)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# Bruno
# 29
# bom dia
# 1.76
