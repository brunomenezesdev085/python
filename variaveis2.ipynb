# %% [markdown]
# <a href="https://colab.research.google.com/github/brunomenezesdev085/python/blob/main/variaveis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input("Digite seu nome:")
idade = input("Digite sua idade:")
altura = input("Digite sua altura:")
fruta_favorita = input('Digite sua fruta favorita?')
#sem f string
print('Olá', nome)
print('Voce tem', idade, 'anos de idade')
print('Olá', nome + ', voce tem', idade, 'anos de idade, e ', altura, 'm.')

#com f-string

print(f'Olá {nome}, voce tem {idade} anos de idade,  e a sua fruta favorita é {fruta_favorita}.')
# Out:
# Digite seu nome:Bruno
# Digite sua idade:29
# Digite sua altura:1,76
# Digite sua fruta favorita?banana
# Olá Bruno
# Voce tem 29 anos de idade
# Olá Bruno, voce tem 29 anos de idade, e  1,76 m.
# olaBruno, voce tem 29 anos de idade,  e a sua fruta favorita é banana.
